# %%
# Import opencv
import cv2 

# Import Operating System
import os

import numpy as np

from skimage.metrics import structural_similarity as ssim
import argparse

# %%
mainDir = "/home/somu/Documents/shot boundry detection/New folder (6)"

print(os.listdir(mainDir))
# Out:
# ['images']

# %%
def options():
    parser = argparse.ArgumentParser(description="Read image metadata")
    parser.add_argument("-o", "--first", help="Input image file.", required=True)
    parser.add_argument("-c", "--second", help="Input image file.", required=True)
    args = parser.parse_args()
    return args

# %%
def mse(imageA, imageB):
    # the 'Mean Squared Error' between the two images is the sum of the squared difference between the two images
    mse_error = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
    mse_error /= float(imageA.shape[0] * imageA.shape[1])
    # return the MSE. The lower the error, the more "similar" the two images are.
    return mse_error

# %%
def compare(imageA, imageB):
 # Calculate the MSE and SSIM
    m = mse(imageA, imageB)
    s = ssim(imageA, imageB)
# Return the SSIM. The higher the value, the more "similar" the two images are.
    return s

# %%
for subDir in os.listdir(mainDir):
    IMAGES_PATH = os.path.join(mainDir, subDir)
    if(os.path.isdir(IMAGES_PATH)):
        print("Reading images from : " + IMAGES_PATH)
        
        images = os.listdir(IMAGES_PATH)
        
        for i in range(len(images)-1):
            print(i+1)            
            IMAGE_PATH1 = os.path.join(IMAGES_PATH, str(i+1)+'.jpg')
            IMAGE_PATH2 = os.path.join(IMAGES_PATH, str(i+2)+'.jpg')
            
                        
            image1 = cv2.imread(IMAGE_PATH1) 
            image2 = cv2.imread(IMAGE_PATH2) 
            gray1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
            gray2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)
            
            gray1 = cv2.resize(gray1, [500,500])
            gray2 = cv2.resize(gray2, [500,500])
            mse_value = mse(gray1, gray2)
            ssim_value = compare(gray1, gray2) 
            print('---MSE and SSIM Between',IMAGE_PATH1 +" and "+ IMAGE_PATH2)
            print("MSE:", mse_value)
            print("SSIM:", ssim_value)
            
           
        # cv2.imshow('image', gray1)
             
            # Maintain output window utill
            # user presses a key
            #cv2.waitKey(0)        
  
            # Destroying present windows on screen
           # cv2.destroyAllWindows()
# Out:
# Reading images from : /home/somu/Documents/shot boundry detection/New folder (6)/images
# 1
# ---MSE and SSIM Between /home/somu/Documents/shot boundry detection/New folder (6)/images/1.jpg and /home/somu/Documents/shot boundry detection/New folder (6)/images/2.jpg
# MSE: 21.003624
# SSIM: 0.9806725598753714
# 2
# ---MSE and SSIM Between /home/somu/Documents/shot boundry detection/New folder (6)/images/2.jpg and /home/somu/Documents/shot boundry detection/New folder (6)/images/3.jpg
# MSE: 39.433844
# SSIM: 0.9678857724200236
# 3
# ---MSE and SSIM Between /home/somu/Documents/shot boundry detection/New folder (6)/images/3.jpg and /home/somu/Documents/shot boundry detection/New folder (6)/images/4.jpg
# MSE: 32.882268
# SSIM: 0.9692815877867018
# 4
# ---MSE and SSIM Between /home/somu/Documents/shot boundry detection/New folder (6)/images/4.jpg and /home/somu/Documents/shot boundry detection/New folder (6)/images/5.jpg
# MSE: 89.242092
# SSIM: 0.9521364328564743
# 5
# ...

# %%
image4 = cv2.imread('/home/somu/Documents/shot boundry detection/New folder (6)/45.jpg')

# %%
os.path.join(IMAGES_PATH, str(1)+'.jpg')
# Out:
# '/home/somu/Documents/shot boundry detection/New folder (6)/images/1.jpg'

# %%
# Out:
# 149
